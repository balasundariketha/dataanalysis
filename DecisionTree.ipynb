# %% [markdown]
# <a href="https://colab.research.google.com/github/balasundariketha/dataanalysis/blob/main/DecisionTree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Load libraries
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz,plot_tree
# !pip install image
from IPython.display import Image
# Out:
# Requirement already satisfied: image in /usr/local/lib/python3.10/dist-packages (1.5.33)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from image) (9.4.0)
# Requirement already satisfied: django in /usr/local/lib/python3.10/dist-packages (from image) (5.0.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from image) (1.16.0)
# Requirement already satisfied: asgiref<4,>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from django->image) (3.7.2)
# Requirement already satisfied: sqlparse>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from django->image) (0.4.4)
# Requirement already satisfied: typing-extensions>=4 in /usr/local/lib/python3.10/dist-packages (from asgiref<4,>=3.7.0->django->image) (4.9.0)

# %%
df=pd.read_csv("/content/demoDT (1).csv")
print(df)
# Out:
#    State  Literacy   Cleanliness   Crime_Rate  good
# 0      A        92            90           54     0
# 1      B        56            67           50     1
# 2      C        78            80           62     0
# 3      D        85            75           48     1
# 4      E        60            82           55     0
# 5      F        72            78           60     1
# 6      G        88            85           45     0
# 7      H        64            70           58     1
# 8      I        90            88           42     0
# 9      J        68            72           65     1
# 10     K        75            79           57     0
# 11     L        82            86           49     1
# 12     M        58            65           63     0
# 13     N        77            76           52     1
# 14     O        94            91           40     0
# 15     P        63            74           61     1
# 16     Q        79            83           47     0
# 17     R        71            68           59     1
# 18     S        86            89           43     0
# 19     T        66            71           64     1
# 20     U        81            81           51     0
# 21     V        70            77           56     1
# 22     W        87            84           46     0
# 23     X        62            69           66     1
# 24     Y        76            73           53     0
# 25     Z        83            87           44     1

# %%
feature_cols=['Literacy',' Cleanliness',' Crime_Rate']
feature=df[feature_cols]#features
Target=df.good#target variable

# %%
#Create Decision Tree classifier object
DT=DecisionTreeClassifier()
#Train Decision Tree Classifier
DT=DT.fit(feature,Target)

# %%
plot_tree(DT)
# Out:
# [Text(0.4444444444444444, 0.9, 'x[1] <= 78.5\ngini = 0.5\nsamples = 26\nvalue = [13, 13]'),
#  Text(0.2222222222222222, 0.7, 'x[1] <= 66.0\ngini = 0.26\nsamples = 13\nvalue = [2, 11]'),
#  Text(0.1111111111111111, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.3333333333333333, 0.5, 'x[0] <= 74.0\ngini = 0.153\nsamples = 12\nvalue = [1, 11]'),
#  Text(0.2222222222222222, 0.3, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(0.4444444444444444, 0.3, 'x[0] <= 76.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(0.3333333333333333, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.5555555555555556, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6666666666666666, 0.7, 'x[1] <= 85.5\ngini = 0.26\nsamples = 13\nvalue = [11, 2]'),
#  Text(0.5555555555555556, 0.5, 'gini = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(0.7777777777777778, 0.5, 'x[1] <= 87.5\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(0.6666666666666666, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.8888888888888888, 0.3, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]')]
